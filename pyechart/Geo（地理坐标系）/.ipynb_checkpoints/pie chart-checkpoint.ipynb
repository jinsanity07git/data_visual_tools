# %%
from pyecharts import Pie

attr = ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"]
v1 = [11, 12, 13, 10, 10, 10]
pie = Pie("饼图-圆环图示例", title_pos='center')
pie.add("", attr, v1, radius=[0, 75], label_text_color=None,
        is_label_show=True, legend_orient='vertical',
        legend_pos='left')
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="44f03ed5f2834308984dbcd749576fe7" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_44f03ed5f2834308984dbcd749576fe7 = echarts.init(document.getElementById('44f03ed5f2834308984dbcd749576fe7'), 'light', {renderer: 'canvas'});
#
# var option_44f03ed5f2834308984dbcd749576fe7 = {
#     "title": [
#         {
#             "text": "\u997c\u56fe-\u5706\u73af\u56fe\u793a\u4f8b",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 7736750,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u886c\u886b",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u7f8a\u6bdb\u886b",
#                     "value": 12
#                 },
#                 {
#                     "name": "\u96ea\u7eba\u886b",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u88e4\u5b50",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u889c\u5b50",
#                     "value": 10
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 7736750
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "left",
#             "top": "top",
#             "orient": "vertical",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_44f03ed5f2834308984dbcd749576fe7.setOption(option_44f03ed5f2834308984dbcd749576fe7);
#
#     });
# </script>

# %%
import random
from pyecharts import Pie

attr = ['A', 'B', 'C', 'D', 'E', 'F']
pie = Pie("饼图示例", width=1000, height=600)
pie.add("", attr, [random.randint(0, 100) for _ in range(6)],
        radius=[50, 55], center=[25, 50], is_random=True)
pie.add("", attr, [random.randint(20, 100) for _ in range(6)],
        radius=[0, 45], center=[25, 50], rosetype='area')
pie.add("", attr, [random.randint(0, 100) for _ in range(6)],
        radius=[50, 55], center=[65, 50], is_random=True)
pie.add("", attr, [random.randint(20, 100) for _ in range(6)],
        radius=[0, 45], center=[65, 50], rosetype='radius')
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="42ffd2280fcc4425b72e18e67eae1c40" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_42ffd2280fcc4425b72e18e67eae1c40 = echarts.init(document.getElementById('42ffd2280fcc4425b72e18e67eae1c40'), 'light', {renderer: 'canvas'});
#
# var option_42ffd2280fcc4425b72e18e67eae1c40 = {
#     "title": [
#         {
#             "text": "\u997c\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 8086197,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "A",
#                     "value": 77
#                 },
#                 {
#                     "name": "B",
#                     "value": 96
#                 },
#                 {
#                     "name": "C",
#                     "value": 90
#                 },
#                 {
#                     "name": "D",
#                     "value": 15
#                 },
#                 {
#                     "name": "E",
#                     "value": 97
#                 },
#                 {
#                     "name": "F",
#                     "value": 11
#                 }
#             ],
#             "radius": [
#                 "50%",
#                 "55%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 8086197
#         },
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "A",
#                     "value": 58
#                 },
#                 {
#                     "name": "B",
#                     "value": 21
#                 },
#                 {
#                     "name": "C",
#                     "value": 100
#                 },
#                 {
#                     "name": "D",
#                     "value": 89
#                 },
#                 {
#                     "name": "E",
#                     "value": 82
#                 },
#                 {
#                     "name": "F",
#                     "value": 44
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "45%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 8086197
#         },
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "A",
#                     "value": 82
#                 },
#                 {
#                     "name": "B",
#                     "value": 36
#                 },
#                 {
#                     "name": "C",
#                     "value": 11
#                 },
#                 {
#                     "name": "D",
#                     "value": 46
#                 },
#                 {
#                     "name": "E",
#                     "value": 58
#                 },
#                 {
#                     "name": "F",
#                     "value": 3
#                 }
#             ],
#             "radius": [
#                 "50%",
#                 "55%"
#             ],
#             "center": [
#                 "65%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 8086197
#         },
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "A",
#                     "value": 67
#                 },
#                 {
#                     "name": "B",
#                     "value": 35
#                 },
#                 {
#                     "name": "C",
#                     "value": 32
#                 },
#                 {
#                     "name": "D",
#                     "value": 27
#                 },
#                 {
#                     "name": "E",
#                     "value": 59
#                 },
#                 {
#                     "name": "F",
#                     "value": 60
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "45%"
#             ],
#             "center": [
#                 "65%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 8086197
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B",
#                 "C",
#                 "D",
#                 "E",
#                 "F"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#ef5b9c",
#         "#61a0a8",
#         "#918597",
#         "#546570",
#         "#fab27b",
#         "#f6f5ec",
#         "#1d953f",
#         "#6d8346",
#         "#726930",
#         "#2f4554",

# %%
from pyecharts import Pie,Style

pie = Pie('各类电影中"好片"所占的比例', "数据来着豆瓣", title_pos='center')
style = Style(
    title_color="black",
    subtitle_color="#aaa"
)
pie_style = style.add(
    label_pos="center",
    is_label_show=True,
    label_text_color=None
)

pie.add("", ["剧情", ""], [25, 75], center=[10, 30],
        radius=[18, 24], **pie_style)
pie.add("", ["奇幻", ""], [24, 76], center=[30, 30],
        radius=[18, 24], **pie_style)
pie.add("", ["爱情", ""], [14, 86], center=[50, 30],
        radius=[18, 24], **pie_style)
pie.add("", ["惊悚", ""], [11, 89], center=[70, 30],
        radius=[18, 24], **pie_style)
pie.add("", ["冒险", ""], [27, 73], center=[90, 30],
        radius=[18, 24], **pie_style)
pie.add("", ["动作", ""], [15, 85], center=[10, 70],
        radius=[18, 24], **pie_style)
pie.add("", ["喜剧", ""], [54, 46], center=[30, 70],
        radius=[18, 24], **pie_style)
pie.add("", ["科幻", ""], [26, 74], center=[50, 70],
        radius=[18, 24], **pie_style)
pie.add("", ["悬疑", ""], [25, 75], center=[70, 70],
        radius=[18, 24], **pie_style)
pie.add("", ["犯罪", ""], [28, 72], center=[90, 70],
        radius=[18, 24], legend_top="center", **pie_style)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="fcc290e759494cf6aeb7725b5b25be66" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_fcc290e759494cf6aeb7725b5b25be66 = echarts.init(document.getElementById('fcc290e759494cf6aeb7725b5b25be66'), 'light', {renderer: 'canvas'});
#
# var option_fcc290e759494cf6aeb7725b5b25be66 = {
#     "title": [
#         {
#             "text": "\u5404\u7c7b\u7535\u5f71\u4e2d\"\u597d\u7247\"\u6240\u5360\u7684\u6bd4\u4f8b",
#             "subtext": "\u6570\u636e\u6765\u7740\u8c46\u74e3",
#             "left": "center",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2734362,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u5267\u60c5",
#                     "value": 25
#                 },
#                 {
#                     "value": 75
#                 }
#             ],
#             "radius": [
#                 "18%",
#                 "24%"
#             ],
#             "center": [
#                 "10%",
#                 "30%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "center",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 2734362
#         },
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u5947\u5e7b",
#                     "value": 24
#                 },
#                 {
#                     "value": 76
#                 }
#             ],
#             "radius": [
#                 "18%",
#                 "24%"
#             ],
#             "center": [
#                 "30%",
#                 "30%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "center",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 2734362
#         },
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u7231\u60c5",
#                     "value": 14
#                 },
#                 {
#                     "value": 86
#                 }
#             ],
#             "radius": [
#                 "18%",
#                 "24%"
#             ],
#             "center": [
#                 "50%",
#                 "30%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "center",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 2734362
#         },
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u60ca\u609a",
#                     "value": 11
#                 },
#                 {
#                     "value": 89
#                 }
#             ],
#             "radius": [
#                 "18%",
#                 "24%"
#             ],
#             "center": [
#                 "70%",
#                 "30%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "center",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 2734362
#         },
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u5192\u9669",
#                     "value": 27
#                 },
#                 {
#                     "value": 73
#                 }
#             ],
#             "radius": [
#                 "18%",
#                 "24%"
#             ],
#             "center": [
#                 "90%",
#                 "30%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "center",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 2734362
#         },
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u52a8\u4f5c",
#                     "value": 15
#                 },
#                 {
#                     "value": 85
#                 }
#             ],
#             "radius": [
#                 "18%",
#                 "24%"
#             ],
#             "center": [
#                 "10%",
#                 "70%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "center",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 2734362
#         },
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "\u559c\u5267",
#                     "value": 54
#                 },
#                 {
#                     "value": 46
#                 }
#             ],
#             "radius": [
#                 "18%",
#                 "24%"
#             ],
#             "center": [
