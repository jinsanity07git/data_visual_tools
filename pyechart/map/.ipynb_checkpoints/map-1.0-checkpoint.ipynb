# %% [markdown]
# ### 1.install map package for first time use
# http://pyecharts.org/#/zh-cn/customize_map

# %%
# import sys
# !{sys.executable} -m  pip install echarts-countries-pypkg
# !{sys.executable} -m  pip install echarts-china-provinces-pypkg
# !{sys.executable} -m  pip install echarts-china-cities-pypkg
# !{sys.executable} -m  pip install echarts-china-counties-pypkg
# !{sys.executable} -m  pip install echarts-china-misc-pypkg

# %% [markdown]
# ### 2.reboot jupyter notebook

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Jun 12 14:10:38 2018

@author: jinsa_2cyyutj
# """
import pandas as pd
from pyecharts import Map

# %%
## inputs  in instruction page to determine sheetname& map type
input_fname = 'inputs.xlsx'
df_inst = pd.read_excel(input_fname,sheet_name ='说明页',header = None)     
Sheet_name = df_inst[2][3]              ## read map type


###  inputs: 1.图形初始化  
df1=pd.read_excel(input_fname,sheet_name =Sheet_name,header = None)
ls1 = df1[0][4:18].tolist()
Type,title,subtitle,width,height,title_pos,title_top,title_color,subtitle_color,title_text_size,subtitle_text_size,background_color,page_title,renderer = ([] for i in range(14))
Type,title,subtitle,width,height,title_pos,title_top,title_color,subtitle_color,title_text_size,subtitle_text_size,background_color,page_title,renderer = ls1

# ###
#     dic = {'中国地图':'china', '世界地图'：'world'} ## conver to attribute by dict
# if Sheet_name == '中国地图':
# #     Map_type = dic[Sheet_name]
# Sheet_name == '省份地图':

Map_type = Type

# %%
Map_type
# Out:
# 'world'

# %%
## inputs: 2.地名和数值
name = df1[3][5:].dropna().tolist() ##      3 地名
value = df1[4][5:].dropna().tolist() ##     4 数值
## inputs: 3.显示区域热力图
ls3 = df1[8][5:7].tolist()
is_visualmap,visual_range = ([] for i in range(2))      ### define var
is_visualmap,visual_range = ls3                         ### assign value

# %% [markdown]
# ### Converting a string representation of a list into an actual list object [duplicate]
# https://stackoverflow.com/questions/10775894/converting-a-string-representation-of-a-list-into-an-actual-list-object
# eval(visual_range)

# %%
map = Map(title,subtitle,width=width,height=height,
           title_pos=title_pos,title_top=title_top,title_color=title_color,
            subtitle_color=subtitle_color,title_text_size=title_text_size,
            subtitle_text_size=subtitle_text_size,background_color=background_color,
            page_title=page_title,renderer= renderer)
map.add("", name, value, maptype=Map_type,
        is_visualmap=is_visualmap,                  ##  VisualMap 组件
#          is_piecewise=True,
#         visual_text_color="#999",
#         visual_range_text=["200", "0"],
        visual_range =  eval(visual_range)            ##设置 指定组件的允许的最小值与最大值。默认为 [0, 100]  ### convet string to list
       )

map
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'world': '/nbextensions/echarts-countries-js/world'
#         }
#     });
# </script>
#     <div id="57a02d260a3844038b3dcf3edb3a7230" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'world'], function(echarts) {
#
# var myChart_57a02d260a3844038b3dcf3edb3a7230 = echarts.init(document.getElementById('57a02d260a3844038b3dcf3edb3a7230'), 'light', {renderer: 'canvas'});
#
# var option_57a02d260a3844038b3dcf3edb3a7230 = {
#     "title": [
#         {
#             "text": "\u5168\u56fd\u5730\u56fe\u793a\u4f8b",
#             "subtext": NaN,
#             "left": "left",
#             "top": "top",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 8494037,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "China",
#                     "value": 50
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 400
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 20
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 7
#                 },
#                 {
#                     "name": "United States",
#                     "value": 300
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": true
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "backgroundColor": "#fff",
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 0,
#         "max": 500,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {},
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true
#     }
# };
# myChart_57a02d260a3844038b3dcf3edb3a7230.setOption(option_57a02d260a3844038b3dcf3edb3a7230);
#
#     });
# </script>
