# %%
# -*- coding: utf-8 -*-
"""
Created on Tue May 30 22:10:38 2018

@author: jinsa_2cyyutj
# """
import pandas as pd
from wordcloud import WordCloud
#import codecs
import jieba
import os
from os import path
from pyecharts import WordCloud as WC
from openpyxl import load_workbook,Workbook

# %%
## inputs
# Dir = os.path.join('C:/Users/zihao','pyechart','wordcloud','test.txt')
input_fname = 'inputs.xlsx'
df2=pd.read_excel(input_fname,sheet_name ='文本页',header = None)
comment_text = df2.to_string( index=False)
df1=pd.read_excel(input_fname,sheet_name ='绘图页',header = None)
Num = 20 ## 筛选词频前20的词汇

STOP = df1[8][5:].dropna().tolist()  ## 获取过滤词汇：

##inputs: 1.图形初始化  
ls3 = df1[0][4:18].tolist()
Type,title,subtitle,width,height,title_pos,title_top,title_color,subtitle_color,title_text_size,subtitle_text_size,background_color,page_title,renderer = ([] for i in range(14))
Type,title,subtitle,width,height,title_pos,title_top,title_color,subtitle_color,title_text_size,subtitle_text_size,background_color,page_title,renderer = ls3

# %%
def range_Toend_clear(work_sheet,start_row = 'D',start_cell = 'D6',end_row = 'E'):
    '''1.select range to the end of the row 
       2. delete all the value
    '''

    end_cell_num = len(work_sheet[start_row])
    for row in ws1[start_cell : end_row+'{}'.format(end_cell_num)] :
        for cell in row :
            cell.value = None

# %%
def range_assign_value(name,value,work_sheet,start_row = 'D',start_cell = 'D6',end_row = 'E'):
    '''1.select range to the end of the row 
       2. assign value in pair lists
    '''
    end_cell_num = len(name) + 5   ## row star from row_6
    i = 0
    for row in ws1[start_cell : 'E{}'.format(end_cell_num)] :
        row[0].value = name[i]
        row[1].value = value[i]
        i=i+1

# %%
def gen_from_txt(comment_text,STOP,Num):
    """split string and return wordcloud lists"""

    cloud = WordCloud(stopwords=STOP)
    #结巴分词，生成字符串，如果不通过分词，无法直接生成正确的中文词云
    cut_text = " ".join(jieba.cut(comment_text))
    word_cloud = cloud.generate(cut_text)
    wd = word_cloud.process_text(cut_text)  ### Splits a long text into words, eliminates the stopwords.
    list_tup = sorted(wd.items(), key=lambda x: x[1],reverse=True)
    source_list = list_tup[0:Num]
    ### return a list of tuple and filter first 20 elements]
    name, value = zip(*source_list)     ### return two tuple
    name, value = [list(c) for c in zip(*source_list)]
    return name, value

# %%
if __name__ == '__main__':
    wordcloud = WC(title,subtitle,width=width,height=height,
           title_pos=title_pos,title_top=title_top,title_color=title_color,
            subtitle_color=subtitle_color,title_text_size=title_text_size,
            subtitle_text_size=subtitle_text_size,background_color=background_color,
            page_title=page_title,renderer= renderer)
    if Type == 2 :        ## 文本页类型
        
        name, value = gen_from_txt(comment_text,STOP,Num)
        wordcloud.add("", name, value, word_size_range=[20, 100])     
        wordcloud.render(title+'Type{}'.format(Type)+ '.html')   
        ###update worksheet in input column ##
        wb=load_workbook(input_fname)
        ws1=wb['绘图页']
        ### clear exsiting data
        range_Toend_clear(ws1,start_row = 'D',start_cell = 'D6',end_row = 'E')
        ### write counting data
        range_assign_value(name,value,work_sheet=ws1,start_row = 'D',start_cell = 'D6',end_row = 'E')
        ### save excel file
        wb.save(input_fname +'_Type2_result.xlsx')
        
    elif Type == 1 :        ## 手动输入词汇及词频
        name = df1[3][5:].dropna().tolist() ##      3 词汇列
        value = df1[4][5:].dropna().tolist() ##     4 词频列
        wordcloud.add("", name, value, word_size_range=[20, 100])          
        wordcloud.render(title+'Type{}'.format(Type)+ '.html')    
    else :
        print ('请输入正确的绘图input类型' + '/n' + '<--制图类型： 手动输入词汇及词频为‘1’， 在文本页输入文本为‘2’')

# %%
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="4e72d8467aa042748b19145719f1057a" style="width:800px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_4e72d8467aa042748b19145719f1057a = echarts.init(document.getElementById('4e72d8467aa042748b19145719f1057a'), 'light', {renderer: 'canvas'});
#
# var option_4e72d8467aa042748b19145719f1057a = {
#     "title": [
#         {
#             "text": "\u8bcd\u4e91\u56fe",
#             "subtext": NaN,
#             "left": "left",
#             "top": "top",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 2902767,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u9a91\u58eb",
#                     "value": 14,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,47,63)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9632\u5b88",
#                     "value": 11,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(131,83,36)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u52c7\u58eb",
#                     "value": 8,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(35,65,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e50\u798f",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(67,110,22)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd9\u4e2a",
#                     "value": 5,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,48,159)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6362\u9632",
#                     "value": 5,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(22,29,63)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6848\u4f8b",
#                     "value": 5,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(141,73,49)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "JR",
#                     "value": 5,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,93,56)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fdb\u653b",
#                     "value": 5,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(83,83,73)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u6b21",
#                     "value": 4,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(8,59,141)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7a7a\u5207",
#                     "value": 4,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,115,145)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6beb\u65e0",
#                     "value": 4,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(12,66,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u534f\u9632",
#                     "value": 4,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(116,35,64)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u884c",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,119,138)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e93\u91cc",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,7,38)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53ef\u4ee5",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(46,94,95)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56de\u5408",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(157,143,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9519\u8bef",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,57,160)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0b\u9762",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(4,146,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u610f\u8bc6",
#                     "value": 3,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(5,39,156)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",

# %%
# ## 将list转换为 series
# import pandas as pd
# df = pd.Series( (v for v in STOP) )
# print (df)

# %% [markdown]
# ###  怎么去除“Building prefix dict from the default dictionary ...”的提示 #529
# [click here](https://github.com/fxsjy/jieba/issues/529)
# 找到jieba库的__init__.py， 大约28~30行左右，
# ```
# log_console = logging.StreamHandler(sys.stderr)
# default_logger = logging.getLogger(__name__)
# default_logger.setLevel(logging.DEBUG)
# default_logger.addHandler(log_console)
# ```
# 将default_logger.setLevel(logging.DEBUG) 改为 default_logger.setLevel(logging.INFO) 试试。
