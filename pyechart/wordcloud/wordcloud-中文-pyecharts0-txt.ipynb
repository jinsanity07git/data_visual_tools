# %%
# -*- coding: utf-8 -*-
"""
Created on Tue May 30 22:10:38 2018

@author: jinsa_2cyyutj
"""

#wordcloud生成中文词云

from wordcloud import WordCloud
#import codecs
import jieba
#import jieba.analyse as analyse
from scipy.misc import imread
import os
from os import path
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont

STOP=['然后', '因为', '最后', '没有','他们','一样','赞赏','举报','引用','此人','回复','我要','真的','发表']

Dir = os.path.join('pyechart','wordcloud','test.txt')
Dir_font = os.path.join('pyechart','wordcloud','HYQiHei-25JF.ttf')
Dir_pic = os.path.join('pyechart','wordcloud',"pjl_cloud4.jpg")

# %%
 cloud = WordCloud(
        #设置字体，不指定就会出现乱码
#        font_path="D:/experiment/HYQiHei-25JF.ttf",

        stopwords=STOP ,
        #font_path=path.join(d,'simsun.ttc'),
        #设置背景色
        background_color='#222222',
        #词云形状
 #       mask=color_mask,
        #允许最大词汇
        max_words=2000,
        #最大号字体
        max_font_size=40 )

comment_text = open('pyechart\\wordcloud\\test.txt','r').read()
#结巴分词，生成字符串，如果不通过分词，无法直接生成正确的中文词云
cut_text = " ".join(jieba.cut(comment_text))
word_cloud = cloud.generate(cut_text)

wd = word_cloud.process_text(cut_text)

list_tup = sorted(wd.items(), key=lambda x: x[1],reverse=True)

source_list = list_tup[0:20]
### return a list of tuple and filter first 20 elements]

name, value = zip(*source_list)     ### return two tuple

name, value = [list(c) for c in zip(*source_list)]

# %%
import pandas as pd
df = pd.Series( (v for v in name) )

print (df)
# Out:
# 0      库里
# 1      三分
# 2      防守
# 3      骑士
# 4      乐福
# 5     杜兰特
# 6      勇士
# 7      比赛
# 8      进攻
# 9      机会
# 10    三分球
# 11     篮下
# 12     出手
# 13     一次
# 14     一个
# 15     南斯
# 16     突破
# 17    第四节
# 18     有效
# 19     内线
# dtype: object

# %%
from pyecharts import WordCloud

wordcloud = WordCloud(width=1300, height=620)
wordcloud.add("", name, value, word_size_range=[20, 100])
wordcloud
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="e5f0b00961b74cae899de1b5b6feffc7" style="width:1300px;height:620px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_e5f0b00961b74cae899de1b5b6feffc7 = echarts.init(document.getElementById('e5f0b00961b74cae899de1b5b6feffc7'), 'light', {renderer: 'canvas'});
#
# var option_e5f0b00961b74cae899de1b5b6feffc7 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "\u4e0b\u8f7d\u56fe\u7247"
#             },
#             "restore": {
#                 "show": true
#             },
#             "dataView": {
#                 "show": true
#             }
#         }
#     },
#     "series_id": 6481829,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u5e93\u91cc",
#                     "value": 90,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(68,88,28)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e09\u5206",
#                     "value": 40,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(103,26,150)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9632\u5b88",
#                     "value": 31,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,90,89)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9a91\u58eb",
#                     "value": 28,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,3,135)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e50\u798f",
#                     "value": 26,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(128,141,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u675c\u5170\u7279",
#                     "value": 23,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(132,67,9)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u52c7\u58eb",
#                     "value": 17,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(80,102,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6bd4\u8d5b",
#                     "value": 15,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(159,146,62)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fdb\u653b",
#                     "value": 15,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,20,95)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u673a\u4f1a",
#                     "value": 14,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(59,84,156)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e09\u5206\u7403",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(0,66,131)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7bee\u4e0b",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(21,76,46)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u51fa\u624b",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(153,56,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u6b21",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(56,3,82)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e00\u4e2a",
#                     "value": 11,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(127,77,57)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5357\u65af",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,157,43)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7a81\u7834",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(20,71,22)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b2c\u56db\u8282",
#                     "value": 9,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(30,73,22)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6709\u6548",
#                     "value": 9,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,135,64)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5185\u7ebf",
#                     "value": 9,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,86,113)"
#                         }
#                     }
#                 }
#             ]
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "color
